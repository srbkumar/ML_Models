# %% [markdown]
# **Problem Statement**:
# The Pima Indians Diabetes Dataset involves predicting the onset of diabetes within 5 years in Pima Indians given medical details.
# It is a binary (2-class) classification problem. The number of observations for each class is not balanced. There are 768 observations with 8 input variables and 1 output variable. Missing values are believed to be encoded with zero values. The variable names are as follows:
# 1.	Number of times pregnant.
# 2.	Plasma glucose concentration 2 hours in an oral glucose tolerance test.
# 3.	Diastolic blood pressure (mm Hg).
# 4.	Triceps skinfold thickness (mm).
# 5.	2-Hour serum insulin (mu U/ml).
# 6.	Body mass index (weight in kg/(height in m)^2).
# 7.	Diabetes pedigree function.
# 8.	Age (years).
# 9.	Is Diabetic (0 or 1).

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from xgboost import XGBClassifier
import pickle
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# %%
# Reading the csv file and creting the data
data = pd.read_csv('pima-indians-diabetes.csv')

# %%
data.head()
# Out:
#    Number of times pregnant  Plasma glucose concentration  \
# 0                         6                           148
# 1                         1                            85
# 2                         8                           183
# 3                         1                            89
# 4                         0                           137
#
#    Diastolic blood pressure (mm Hg)  Triceps skinfold thickness (mm)  \
# 0                                72                               35
# 1                                66                               29
# 2                                64                                0
# 3                                66                               23
# 4                                40                               35
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                               0
# 1                               0
# 2                               0
# 3                              94
# 4                             168
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age  Is Diabetic
# 0   50            1
# 1   31            0
# 2   32            1
# 3   21            0
# 4   33            1

# %%
data.columns
# Out:
# Index(['Number of times pregnant', 'Plasma glucose concentration',
#        'Diastolic blood pressure (mm Hg)', 'Triceps skinfold thickness (mm)',
#        '2-Hour serum insulin (mu U/ml)',
#        'Body mass index (weight in kg/(height in m)^2)',
#        'Diabetes pedigree function', 'Age', 'Is Diabetic'],
#       dtype='object')

# %% [markdown]
# Now out of the 8 feature columns, apart from the 'Number of times pregnant' field, none of the columns should have the value as 0. But, as mentioned in the above data description the Missing values has been replaced y 0. We need to replace it first with NaN and then impute it.

# %%
cols = ['Plasma glucose concentration',
       'Diastolic blood pressure (mm Hg)', 'Triceps skinfold thickness (mm)',
       '2-Hour serum insulin (mu U/ml)',
       'Body mass index (weight in kg/(height in m)^2)',
       'Diabetes pedigree function', 'Age']

# %%
for col in cols:
    data[col] = data[col].replace(0,np.nan)

# %%
# checking for missing values
data.isna().sum()
# Out:
# Number of times pregnant                            0
# Plasma glucose concentration                        5
# Diastolic blood pressure (mm Hg)                   35
# Triceps skinfold thickness (mm)                   227
# 2-Hour serum insulin (mu U/ml)                    374
# Body mass index (weight in kg/(height in m)^2)     11
# Diabetes pedigree function                          0
# Age                                                 0
# Is Diabetic                                         0
# dtype: int64

# %%
data.describe()
# Out:
#        Number of times pregnant  Plasma glucose concentration  \
# count                768.000000                    763.000000
# mean                   3.845052                    121.686763
# std                    3.369578                     30.535641
# min                    0.000000                     44.000000
# 25%                    1.000000                     99.000000
# 50%                    3.000000                    117.000000
# 75%                    6.000000                    141.000000
# max                   17.000000                    199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skinfold thickness (mm)  \
# count                        733.000000                       541.000000
# mean                          72.405184                        29.153420
# std                           12.382158                        10.476982
# min                           24.000000                         7.000000
# 25%                           64.000000                        22.000000
# 50%                           72.000000                        29.000000
# 75%                           80.000000                        36.000000
# max                          122.000000                        99.000000
#
#        2-Hour serum insulin (mu U/ml)  \
# count                      394.000000
# mean                       155.548223
# std                        118.775855
# min                         14.000000
# 25%                         76.250000
# 50%                        125.000000
# 75%                        190.000000
# max                        846.000000
#
#        Body mass index (weight in kg/(height in m)^2)  \
# count                                      757.000000
# mean                                        32.457464
# std                                          6.924988
# min                                         18.200000
# 25%                                         27.500000
# 50%                                         32.300000
# 75%                                         36.600000
# max                                         67.100000
#
#        Diabetes pedigree function         Age  Is Diabetic
# count                  768.000000  768.000000   768.000000
# mean                     0.471876   33.240885     0.348958
# std                      0.331329   11.760232     0.476951
# min                      0.078000   21.000000     0.000000
# 25%                      0.243750   24.000000     0.000000
# 50%                      0.372500   29.000000     0.000000
# 75%                      0.626250   41.000000     1.000000
# max                      2.420000   81.000000     1.000000

# %%
#imputing the missing values
data['Plasma glucose concentration']= data['Plasma glucose concentration'].fillna(data['Plasma glucose concentration'].mode()[0])
data['Diastolic blood pressure (mm Hg)']= data['Diastolic blood pressure (mm Hg)'].fillna(data['Diastolic blood pressure (mm Hg)'].mode()[0])
data['Triceps skinfold thickness (mm)']= data['Triceps skinfold thickness (mm)'].fillna(data['Triceps skinfold thickness (mm)'].mean())
data['2-Hour serum insulin (mu U/ml)']= data['2-Hour serum insulin (mu U/ml)'].fillna(data['2-Hour serum insulin (mu U/ml)'].mean())
data['Body mass index (weight in kg/(height in m)^2)']= data['Body mass index (weight in kg/(height in m)^2)'].fillna(data['Body mass index (weight in kg/(height in m)^2)'].mean())

# %%
# checking for missing values
data.isna().sum()
# Out:
# Number of times pregnant                          0
# Plasma glucose concentration                      0
# Diastolic blood pressure (mm Hg)                  0
# Triceps skinfold thickness (mm)                   0
# 2-Hour serum insulin (mu U/ml)                    0
# Body mass index (weight in kg/(height in m)^2)    0
# Diabetes pedigree function                        0
# Age                                               0
# Is Diabetic                                       0
# dtype: int64

# %%
# Seprating x and y labels
x = data.drop('Is Diabetic', axis = 1)
y = data['Is Diabetic']

# %%
x.head()
# Out:
#    Number of times pregnant  Plasma glucose concentration  \
# 0                         6                         148.0
# 1                         1                          85.0
# 2                         8                         183.0
# 3                         1                          89.0
# 4                         0                         137.0
#
#    Diastolic blood pressure (mm Hg)  Triceps skinfold thickness (mm)  \
# 0                              72.0                         35.00000
# 1                              66.0                         29.00000
# 2                              64.0                         29.15342
# 3                              66.0                         23.00000
# 4                              40.0                         35.00000
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                      155.548223
# 1                      155.548223
# 2                      155.548223
# 3                       94.000000
# 4                      168.000000
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age
# 0   50
# 1   31
# 2   32
# 3   21
# 4   33

# %%
# scaling the datapoints
scaler = StandardScaler()
scaled_data = scaler.fit_transform(x)

# %%
scaled_data
# Out:
# array([[ 0.63994726,  0.86840303, -0.02442979, ...,  0.16629174,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.19914997, -0.52034382, ..., -0.85253118,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  2.01704359, -0.68564849, ..., -1.33283341,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 , -0.01769112, -0.02442979, ..., -0.91074963,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.14640039, -1.01625784, ..., -0.34311972,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.93660356, -0.18973447, ..., -0.29945588,
#         -0.47378505, -0.87137393]])

# %%
train_x, test_x, train_y, test_y = train_test_split(scaled_data, y, test_size= 0.25, random_state= 1)

# %%
model = XGBClassifier(objective = 'binary:logistic')
model.fit(train_x, train_y)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
#checking training accuracy
y_pred = model.predict(train_x)
accuracy = accuracy_score(train_y,y_pred)
accuracy
# Out:
# 1.0

# %%
#checking test accuracy
y_pred = model.predict(test_x)
accuracy = accuracy_score(test_y,y_pred)
accuracy
# Out:
# 0.7239583333333334

# %% [markdown]
# ## Hyper-parameter Tuning using GridSearchCV

# %%
param_grid={
    'learning_rate': [1,0.5,0.1,0.01,0.001],
    'max_depth': [3,5],
    'n_estimators': [10,50,100,200]
}

# %%
grid=GridSearchCV(model,param_grid,verbose=3)

# %%
grid.fit(train_x,train_y)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV] learning_rate=1, max_depth=3, n_estimators=10 ...................
# [CV]  learning_rate=1, max_depth=3, n_estimators=10, score=0.698, total=   0.0s
# [CV] learning_rate=1, max_depth=3, n_estimators=10 ...................
# [CV]  learning_rate=1, max_depth=3, n_estimators=10, score=0.757, total=   0.0s
# [CV] learning_rate=1, max_depth=3, n_estimators=10 ...................
# [CV]  learning_rate=1, max_depth=3, n_estimators=10, score=0.765, total=   0.0s
# [CV] learning_rate=1, max_depth=3, n_estimators=10 ...................
# [CV]  learning_rate=1, max_depth=3, n_estimators=10, score=0.739, total=   0.0s
# [CV] learning_rate=1, max_depth=3, n_estimators=10 ...................
# [CV]  learning_rate=1, max_depth=3, n_estimators=10, score=0.765, total=   0.0s
# [CV] learning_rate=1, max_depth=3, n_estimators=50 ...................
# [CV]  learning_rate=1, max_depth=3, n_estimators=50, score=0.724, total=   0.0s
# [CV] learning_rate=1, max_depth=3, n_estimators=50 ...................
# [CV]  learning_rate=1, max_depth=3, n_estimators=50, score=0.722, total=   0.0s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [CV] learning_rate=1, max_depth=3, n_estimators=50 ...................
# [CV]  learning_rate=1, max_depth=3, n_estimators=50, score=0.765, total=   0.0s
# [CV] learning_rate=1, max_depth=3, n_estimators=50 ...................
# [CV]  learning_rate=1, max_depth=3, n_estimators=50, score=0.748, total=   0.0s
# [CV] learning_rate=1, max_depth=3, n_estimators=50 ...................
# [CV]  learning_rate=1, max_depth=3, n_estimators=50, score=0.722, total=   0.0s
# [CV] learning_rate=1, max_depth=3, n_estimators=100 ..................
# [CV]  learning_rate=1, max_depth=3, n_estimators=100, score=0.690, total=   0.1s
# [CV] learning_rate=1, max_depth=3, n_estimators=100 ..................
# [CV]  learning_rate=1, max_depth=3, n_estimators=100, score=0.748, total=   0.1s
# [CV] learning_rate=1, max_depth=3, n_estimators=100 ..................
# [CV]  learning_rate=1, max_depth=3, n_estimators=100, score=0.739, total=   0.1s
# [CV] learning_rate=1, max_depth=3, n_estimators=100 ..................
# [CV]  learning_rate=1, max_depth=3, n_estimators=100, score=0.713, total=   0.1s
# [CV] learning_rate=1, max_depth=3, n_estimators=100 ..................
# [CV]  learning_rate=1, max_depth=3, n_estimators=100, score=0.722, total=   0.1s
# [CV] learning_rate=1, max_depth=3, n_estimators=200 ..................
# [CV]  learning_rate=1, max_depth=3, n_estimators=200, score=0.707, total=   0.1s
# [CV] learning_rate=1, max_depth=3, n_estimators=200 ..................
# [CV]  learning_rate=1, max_depth=3, n_estimators=200, score=0.748, total=   0.1s
# [CV] learning_rate=1, max_depth=3, n_estimators=200 ..................
# [CV]  learning_rate=1, max_depth=3, n_estimators=200, score=0.739, total=   0.1s
# [CV] learning_rate=1, max_depth=3, n_estimators=200 ..................
# [CV]  learning_rate=1, max_depth=3, n_estimators=200, score=0.687, total=   0.1s
# [CV] learning_rate=1, max_depth=3, n_estimators=200 ..................
# [CV]  learning_rate=1, max_depth=3, n_estimators=200, score=0.713, total=   0.1s
# [CV] learning_rate=1, max_depth=5, n_estimators=10 ...................
# [CV]  learning_rate=1, max_depth=5, n_estimators=10, score=0.690, total=   0.0s
# [CV] learning_rate=1, max_depth=5, n_estimators=10 ...................
# [CV]  learning_rate=1, max_depth=5, n_estimators=10, score=0.739, total=   0.0s
# [CV] learning_rate=1, max_depth=5, n_estimators=10 ...................
# [CV]  learning_rate=1, max_depth=5, n_estimators=10, score=0.774, total=   0.0s
# [CV] learning_rate=1, max_depth=5, n_estimators=10 ...................
# [CV]  learning_rate=1, max_depth=5, n_estimators=10, score=0.713, total=   0.0s
# [CV] learning_rate=1, max_depth=5, n_estimators=10 ...................
# [CV]  learning_rate=1, max_depth=5, n_estimators=10, score=0.748, total=   0.0s
# [CV] learning_rate=1, max_depth=5, n_estimators=50 ...................
# [CV]  learning_rate=1, max_depth=5, n_estimators=50, score=0.724, total=   0.0s
# [CV] learning_rate=1, max_depth=5, n_estimators=50 ...................
# [CV]  learning_rate=1, max_depth=5, n_estimators=50, score=0.739, total=   0.0s
# [CV] learning_rate=1, max_depth=5, n_estimators=50 ...................
# [CV]  learning_rate=1, max_depth=5, n_estimators=50, score=0.739, total=   0.0s
# [CV] learning_rate=1, max_depth=5, n_estimators=50 ...................
# [CV]  learning_rate=1, max_depth=5, n_estimators=50, score=0.722, total=   0.0s
# [CV] learning_rate=1, max_depth=5, n_estimators=50 ...................
# [CV]  learning_rate=1, max_depth=5, n_estimators=50, score=0.739, total=   0.0s
# [CV] learning_rate=1, max_depth=5, n_estimators=100 ..................
# [CV]  learning_rate=1, max_depth=5, n_estimators=100, score=0.716, total=   0.1s
# [CV] learning_rate=1, max_depth=5, n_estimators=100 ..................
# [CV]  learning_rate=1, max_depth=5, n_estimators=100, score=0.757, total=   0.1s
# [CV] learning_rate=1, max_depth=5, n_estimators=100 ..................
# [CV]  learning_rate=1, max_depth=5, n_estimators=100, score=0.748, total=   0.1s
# [CV] learning_rate=1, max_depth=5, n_estimators=100 ..................
# [CV]  learning_rate=1, max_depth=5, n_estimators=100, score=0.730, total=   0.1s
# [CV] learning_rate=1, max_depth=5, n_estimators=100 ..................
# [CV]  learning_rate=1, max_depth=5, n_estimators=100, score=0.722, total=   0.1s
# [CV] learning_rate=1, max_depth=5, n_estimators=200 ..................
# [CV]  learning_rate=1, max_depth=5, n_estimators=200, score=0.724, total=   0.1s
# [CV] learning_rate=1, max_depth=5, n_estimators=200 ..................
# [CV]  learning_rate=1, max_depth=5, n_estimators=200, score=0.757, total=   0.1s
# [CV] learning_rate=1, max_depth=5, n_estimators=200 ..................
# [CV]  learning_rate=1, max_depth=5, n_estimators=200, score=0.757, total=   0.1s
# [CV] learning_rate=1, max_depth=5, n_estimators=200 ..................
# [CV]  learning_rate=1, max_depth=5, n_estimators=200, score=0.730, total=   0.1s
# [CV] learning_rate=1, max_depth=5, n_estimators=200 ..................
# [CV]  learning_rate=1, max_depth=5, n_estimators=200, score=0.748, total=   0.1s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=10 .................
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=10, score=0.741, total=   0.0s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=10 .................
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=10, score=0.809, total=   0.0s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=10 .................
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=10, score=0.757, total=   0.0s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=10 .................
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=10, score=0.730, total=   0.0s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=10 .................
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=10, score=0.739, total=   0.0s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=50 .................
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=50, score=0.759, total=   0.0s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=50 .................
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=50, score=0.783, total=   0.0s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=50 .................
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=50, score=0.730, total=   0.0s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=50 .................
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=50, score=0.748, total=   0.0s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=50 .................
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=50, score=0.730, total=   0.0s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=100 ................
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=100, score=0.724, total=   0.1s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=100 ................
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=100, score=0.765, total=   0.1s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=100 ................
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=100, score=0.713, total=   0.1s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=100 ................
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=100, score=0.713, total=   0.1s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=100 ................
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=100, score=0.765, total=   0.1s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=200 ................
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=200, score=0.707, total=   0.1s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=200 ................
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=200, score=0.757, total=   0.1s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=200 ................
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=200, score=0.739, total=   0.1s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=200 ................
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=200, score=0.722, total=   0.1s
# [CV] learning_rate=0.5, max_depth=3, n_estimators=200 ................
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=200, score=0.765, total=   0.1s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=10 .................
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=10, score=0.716, total=   0.0s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=10 .................
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=10, score=0.730, total=   0.0s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=10 .................
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=10, score=0.722, total=   0.0s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=10 .................
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=10, score=0.757, total=   0.0s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=10 .................
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=10, score=0.757, total=   0.0s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=50 .................
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=50, score=0.707, total=   0.0s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=50 .................
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=50, score=0.748, total=   0.0s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=50 .................
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=50, score=0.748, total=   0.0s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=50 .................
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=50, score=0.713, total=   0.0s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=50 .................
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=50, score=0.757, total=   0.1s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=100 ................
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=100, score=0.733, total=   0.1s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=100 ................
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=100, score=0.748, total=   0.1s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=100 ................
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=100, score=0.774, total=   0.1s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=100 ................
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=100, score=0.713, total=   0.1s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=100 ................
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=100, score=0.765, total=   0.1s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=200 ................
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=200, score=0.707, total=   0.1s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=200 ................
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=200, score=0.739, total=   0.1s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=200 ................
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=200, score=0.757, total=   0.1s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=200 ................
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=200, score=0.722, total=   0.1s
# [CV] learning_rate=0.5, max_depth=5, n_estimators=200 ................
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=200, score=0.730, total=   0.1s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=10 .................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=10, score=0.724, total=   0.0s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=10 .................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=10, score=0.783, total=   0.0s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=10 .................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=10, score=0.765, total=   0.0s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=10 .................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=10, score=0.748, total=   0.0s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=10 .................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=10, score=0.722, total=   0.0s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=50 .................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=50, score=0.698, total=   0.0s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=50 .................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=50, score=0.800, total=   0.0s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=50 .................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=50, score=0.757, total=   0.0s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=50 .................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=50, score=0.765, total=   0.0s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=50 .................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=50, score=0.730, total=   0.0s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=100 ................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=100, score=0.724, total=   0.1s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=100 ................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=100, score=0.791, total=   0.1s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=100 ................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=100, score=0.757, total=   0.1s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=100 ................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=100, score=0.730, total=   0.1s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=100 ................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=100, score=0.748, total=   0.1s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=200 ................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=200, score=0.707, total=   0.1s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=200 ................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=200, score=0.748, total=   0.1s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=200 ................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=200, score=0.774, total=   0.1s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=200 ................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=200, score=0.722, total=   0.1s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=200 ................
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=200, score=0.757, total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=10 .................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=10, score=0.733, total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=10 .................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=10, score=0.774, total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=10 .................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=10, score=0.765, total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=10 .................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=10, score=0.739, total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=10 .................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=10, score=0.722, total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=50 .................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=50, score=0.759, total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=50 .................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=50, score=0.809, total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=50 .................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=50, score=0.783, total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=50 .................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=50, score=0.739, total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=50 .................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=50, score=0.748, total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=100 ................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=100, score=0.724, total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=100 ................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=100, score=0.774, total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=100 ................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=100, score=0.757, total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=100 ................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=100, score=0.748, total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=100 ................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=100, score=0.765, total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=200 ................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=200, score=0.733, total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=200 ................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=200, score=0.765, total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=200 ................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=200, score=0.748, total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=200 ................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=200, score=0.757, total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=200 ................
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=200, score=0.774, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, n_estimators=10 ................
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=10, score=0.707, total=   0.0s
# [CV] learning_rate=0.01, max_depth=3, n_estimators=10 ................
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=10, score=0.774, total=   0.0s
# [CV] learning_rate=0.01, max_depth=3, n_estimators=10 ................
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=10, score=0.739, total=   0.0s
# [CV] learning_rate=0.01, max_depth=3, n_estimators=10 ................
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=10, score=0.765, total=   0.0s
# [CV] learning_rate=0.01, max_depth=3, n_estimators=10 ................
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=10, score=0.722, total=   0.0s
# [CV] learning_rate=0.01, max_depth=3, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=50, score=0.707, total=   0.0s
# [CV] learning_rate=0.01, max_depth=3, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=50, score=0.783, total=   0.0s
# [CV] learning_rate=0.01, max_depth=3, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=50, score=0.774, total=   0.0s
# [CV] learning_rate=0.01, max_depth=3, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=50, score=0.757, total=   0.0s
# [CV] learning_rate=0.01, max_depth=3, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=50, score=0.722, total=   0.0s
# [CV] learning_rate=0.01, max_depth=3, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=100, score=0.698, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=100, score=0.783, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=100, score=0.765, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=100, score=0.748, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=100, score=0.713, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=200, score=0.716, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=200, score=0.800, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=200, score=0.765, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=200, score=0.748, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=200, score=0.730, total=   0.1s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=10 ................
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=10, score=0.690, total=   0.0s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=10 ................
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=10, score=0.765, total=   0.0s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=10 ................
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=10, score=0.757, total=   0.0s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=10 ................
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=10, score=0.739, total=   0.0s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=10 ................
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=10, score=0.730, total=   0.0s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=50, score=0.716, total=   0.0s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=50, score=0.757, total=   0.0s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=50, score=0.757, total=   0.1s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=50, score=0.730, total=   0.0s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=50 ................
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=50, score=0.757, total=   0.0s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=100, score=0.707, total=   0.1s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=100, score=0.791, total=   0.1s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=100, score=0.783, total=   0.1s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=100, score=0.730, total=   0.1s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=100 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=100, score=0.748, total=   0.1s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=200, score=0.698, total=   0.2s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=200, score=0.791, total=   0.2s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=200, score=0.765, total=   0.2s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=200, score=0.748, total=   0.2s
# [CV] learning_rate=0.01, max_depth=5, n_estimators=200 ...............
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=200, score=0.739, total=   0.2s
# [CV] learning_rate=0.001, max_depth=3, n_estimators=10 ...............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=10, score=0.707, total=   0.0s
# [CV] learning_rate=0.001, max_depth=3, n_estimators=10 ...............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=10, score=0.774, total=   0.0s
# [CV] learning_rate=0.001, max_depth=3, n_estimators=10 ...............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=10, score=0.748, total=   0.0s
# [CV] learning_rate=0.001, max_depth=3, n_estimators=10 ...............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=10, score=0.748, total=   0.0s
# [CV] learning_rate=0.001, max_depth=3, n_estimators=10 ...............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=10, score=0.722, total=   0.0s
# [CV] learning_rate=0.001, max_depth=3, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=50, score=0.707, total=   0.0s
# [CV] learning_rate=0.001, max_depth=3, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=50, score=0.774, total=   0.0s
# [CV] learning_rate=0.001, max_depth=3, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=50, score=0.748, total=   0.0s
# [CV] learning_rate=0.001, max_depth=3, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=50, score=0.748, total=   0.0s
# [CV] learning_rate=0.001, max_depth=3, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=50, score=0.722, total=   0.0s
# [CV] learning_rate=0.001, max_depth=3, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=100, score=0.707, total=   0.1s
# [CV] learning_rate=0.001, max_depth=3, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=100, score=0.774, total=   0.1s
# [CV] learning_rate=0.001, max_depth=3, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=100, score=0.739, total=   0.1s
# [CV] learning_rate=0.001, max_depth=3, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=100, score=0.765, total=   0.1s
# [CV] learning_rate=0.001, max_depth=3, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=100, score=0.722, total=   0.1s
# [CV] learning_rate=0.001, max_depth=3, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=200, score=0.716, total=   0.1s
# [CV] learning_rate=0.001, max_depth=3, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=200, score=0.774, total=   0.1s
# [CV] learning_rate=0.001, max_depth=3, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=200, score=0.739, total=   0.1s
# [CV] learning_rate=0.001, max_depth=3, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=200, score=0.765, total=   0.1s
# [CV] learning_rate=0.001, max_depth=3, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=200, score=0.722, total=   0.1s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=10 ...............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=10, score=0.690, total=   0.0s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=10 ...............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=10, score=0.757, total=   0.0s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=10 ...............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=10, score=0.748, total=   0.0s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=10 ...............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=10, score=0.722, total=   0.0s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=10 ...............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=10, score=0.730, total=   0.0s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=50, score=0.690, total=   0.0s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=50, score=0.757, total=   0.0s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=50, score=0.739, total=   0.0s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=50, score=0.722, total=   0.0s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=50 ...............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=50, score=0.748, total=   0.1s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=100, score=0.690, total=   0.1s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=100, score=0.765, total=   0.1s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=100, score=0.757, total=   0.1s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=100, score=0.722, total=   0.1s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=100 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=100, score=0.730, total=   0.1s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=200, score=0.698, total=   0.2s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=200, score=0.748, total=   0.2s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=200, score=0.748, total=   0.2s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=200, score=0.739, total=   0.2s
# [CV] learning_rate=0.001, max_depth=5, n_estimators=200 ..............
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=200, score=0.722, total=   0.2s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:   12.6s finished
# GridSearchCV(estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      colsample_bylevel=1, colsample_bynode=1,
#                                      colsample_bytree=1, gamma=0, gpu_id=-1,
#                                      importance_type='gain',
#                                      interaction_constraints='',
#                                      learning_rate=0.300000012,
#                                      max_delta_step=0, max_depth=6,
#                                      min_child_weight=1, missing=nan,
#                                      monotone_constraints='()',
#                                      n_estimators=100, n_jobs=0,
#                                      num_parallel_tree=1, random_state=0,
#                                      reg_alpha=0, reg_lambda=1,
#                                      scale_pos_weight=1, subsample=1,
#                                      tree_method='exact', validate_parameters=1,
#                                      verbosity=None),
#              param_grid={'learning_rate': [1, 0.5, 0.1, 0.01, 0.001],
#                          'max_depth': [3, 5],
#                          'n_estimators': [10, 50, 100, 200]},
#              verbose=3)

# %%
# Best Parameters using GridSearchCV
grid.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}

# %%
#Creating new model using the best parameters
new_model = XGBClassifier(learning_rate=1, max_depth=5, n_estimators= 50)
new_model.fit(train_x,train_y)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=1, max_delta_step=0, max_depth=5,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=50, n_jobs=0, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred_new = new_model.predict(test_x)
accuracy_new = accuracy_score(test_y,y_pred_new)
accuracy_new
# Out:
# 0.75
